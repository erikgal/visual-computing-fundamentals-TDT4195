# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import tqdm
import numpy as np
import utils
import dataloaders
import torchvision
from trainer import Trainer
torch.random.manual_seed(42)
np.random.seed(42)

# %%
print("GPU is available:", torch.cuda.is_available())
# Out:
# GPU is available: True

# %% [markdown]
# ### Dataset

# %%
# Load the dataset and print some stats
batch_size = 64

image_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((32, 32)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize([0.5], [0.5])])

dataloader_train, dataloader_test = dataloaders.load_dataset(batch_size, image_transform)
example_images, _ = next(iter(dataloader_train))
print(f"The tensor containing the images has shape: {example_images.shape} (batch size, number of color channels, height, width)",
      f"The maximum value in the image is {example_images.max()}, minimum: {example_images.min()}", sep="\n\t")
# Out:
# The tensor containing the images has shape: torch.Size([64, 1, 32, 32]) (batch size, number of color channels, height, width)
# 	The maximum value in the image is 1.0, minimum: -1.0

# %%
def create_model():
    """
        Initializes the mode. Edit the code below if you would like to change the model.
    """
    model = nn.Sequential(
        nn.Flatten(), # Flattens the image from shape (batch_size, C, Height, width) to (batch_size, C*height*width)
        nn.Linear(32*32*1, 10)
        # No need to include softmax, as this is already combined in the loss function
    )
    # Transfer model to GPU memory if a GPU is available
    model = utils.to_cuda(model)
    return model


model = create_model()

# %%
# Test if the model is able to do a single forward pass
example_images = utils.to_cuda(example_images)
output = model(example_images)
print("Output shape:", output.shape)
expected_shape = (batch_size, 10) # 10 since mnist has 10 different classes
assert output.shape == expected_shape,    f"Expected shape: {expected_shape}, but got: {output.shape}"
# Out:
# Output shape: torch.Size([64, 10])

# %% [markdown]
# ### Hyperparameters & Loss function

# %%
# Hyperparameters
learning_rate = .02
num_epochs = 5


# Use CrossEntropyLoss for multi-class classification
loss_function = torch.nn.CrossEntropyLoss()

# Define optimizer (Stochastic Gradient Descent)
optimizer = torch.optim.SGD(model.parameters(),
                            lr=learning_rate)

# %% [markdown]
# ### Train model

# %%
trainer = Trainer(
  model=model,
  dataloader_train=dataloader_train,
  dataloader_test=dataloader_test,
  batch_size=batch_size,
  loss_function=loss_function,
  optimizer=optimizer
)
train_loss_dict, test_loss_dict = trainer.train(num_epochs)
# Out:
# ...
# Training epoch 4: 100%|████████████████████████████████████████████| 937/937 [00:12<00:00, 75.79it/s]

# %%
# We can now plot the training loss with our utility script

# Plot loss
utils.plot_loss(train_loss_dict, label="Train Loss")
utils.plot_loss(test_loss_dict, label="Test Loss")
# Limit the y-axis of the plot (The range should not be increased!)
plt.ylim([0, .5])
plt.legend()
plt.xlabel("Global Training Step")
plt.ylabel("Cross Entropy Loss")
plt.savefig(utils.image_output_dir.joinpath("task2a_plot.png"))
plt.show()
final_loss, final_acc = utils.compute_loss_and_accuracy(
    dataloader_test, model, loss_function)
print(f"Final Test loss: {final_loss}. Final Test accuracy: {final_acc}")
# Out:
# Final Test loss: 0.2927984767563783. Final Test accuracy: 0.9166

# %% [markdown]
# ## a)

# %%
def create_model_a():
    """
        Initializes the mode. Edit the code below if you would like to change the model.
    """
    model = nn.Sequential(
        nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),    # Conv2D (kernel size=5, stride=1, padding=2), F = 32
        nn.ReLU(),
        nn.MaxPool2d(2, stride=2),                               # MaxPool2D(kernel size=2, stride=2) 
        nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),   # Conv2D (kernel size=3, stride=1, padding=1), F = 64
        nn.ReLU(),
        nn.MaxPool2d(2, stride=2),                               # MaxPool2D (kernel size=2, stride=2) 
        nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),  # Conv2D (kernel size=3, stride=1, padding=1), F = 128
        nn.ReLU(),
        nn.MaxPool2d(2, stride=2),                               # MaxPool2D (kernel size=2, stride=2)
        nn.Flatten(),                                            # Flatten to (2048, 1)
        nn.Linear(4*4*128, 64),
        nn.ReLU(),
        nn.Linear(64, 10),
        # No need to include softmax, as this is already combined in the loss function
    )
    # Transfer model to GPU memory if a GPU is available
    model = utils.to_cuda(model)
    return model

model_a = create_model_a()

# %% [markdown]
# ### Hyperparameters & Loss function

# %%
# Hyperparameters
learning_rate = .02
num_epochs = 5


# Use CrossEntropyLoss for multi-class classification
loss_function = torch.nn.CrossEntropyLoss()

# Define optimizer (Stochastic Gradient Descent)
optimizer_a = torch.optim.SGD(model_a.parameters(),
                            lr=learning_rate)

# %% [markdown]
# ### Train model

# %%
trainer = Trainer(
  model=model_a,
  dataloader_train=dataloader_train,
  dataloader_test=dataloader_test,
  batch_size=batch_size,
  loss_function=loss_function,
  optimizer=optimizer_a
)
train_loss_dict_a, test_loss_dict_a = trainer.train(num_epochs)
# Out:
# ...
# Training epoch 4: 100%|████████████████████████████████████████████| 937/937 [00:16<00:00, 55.92it/s]

# %%
# We can now plot the training loss with our utility script

# Plot loss
utils.plot_loss(train_loss_dict_a, label="Train Loss")
utils.plot_loss(test_loss_dict_a, label="Test Loss")
# Limit the y-axis of the plot (The range should not be increased!)
plt.ylim([0, 0.4])
plt.legend()
plt.xlabel("Global Training Step")
plt.ylabel("Cross Entropy Loss")
plt.savefig(utils.image_output_dir.joinpath("task2a_plot.png"))
plt.show()
final_loss_a, final_acc_a = utils.compute_loss_and_accuracy(
    dataloader_test, model_a, loss_function)
print(f"Final Test loss: {final_loss_a}. Final Test accuracy: {final_acc_a}")
# Out:
# Final Test loss: 0.03565605740811065. Final Test accuracy: 0.9881

# %% [markdown]
# ## b)

# %% [markdown]
# ### Hyperparameters & Loss function

# %%
# Hyperparameters
learning_rate = .001
num_epochs = 5


# Use CrossEntropyLoss for multi-class classification
loss_function = torch.nn.CrossEntropyLoss()

# Define optimizer (Stochastic Gradient Descent)
optimizer_b = torch.optim.Adam(model_a.parameters(),
                            lr=learning_rate)

# %% [markdown]
# ### Train model

# %%
trainer = Trainer(
  model=model_a,
  dataloader_train=dataloader_train,
  dataloader_test=dataloader_test,
  batch_size=batch_size,
  loss_function=loss_function,
  optimizer=optimizer_b
)
train_loss_dict_b, test_loss_dict_b = trainer.train(num_epochs)
# Out:
# ...
# Training epoch 4: 100%|████████████████████████████████████████████| 937/937 [00:17<00:00, 53.16it/s]

# %%
# We can now plot the training loss with our utility script

# Plot loss
utils.plot_loss(train_loss_dict_a, label="SGD Train Loss")
utils.plot_loss(test_loss_dict_a, label="SGD Test Loss")
utils.plot_loss(train_loss_dict_b, label="Adam Train Loss")
utils.plot_loss(test_loss_dict_b, label="Adam Test Loss")
# Limit the y-axis of the plot (The range should not be increased!)
plt.ylim([0, 0.1])
plt.legend()
plt.xlabel("Global Training Step")
plt.ylabel("Cross Entropy Loss")
plt.savefig(utils.image_output_dir.joinpath("task2b_plot.png"))
plt.show()
final_loss_b, final_acc_b = utils.compute_loss_and_accuracy(
    dataloader_test, model_a, loss_function)
print(f"SGD Final Test loss: {final_loss_a}. SGD Final Test accuracy: {final_acc_a}")
print(f"Adam Final Test loss: {final_loss_b}. Adam Final Test accuracy: {final_acc_b}")
# Out:
# SGD Final Test loss: 0.03565605740811065. SGD Final Test accuracy: 0.9881
# Adam Final Test loss: 0.023904940627714096. Adam Final Test accuracy: 0.9933

# %% [markdown]
# ## c)
